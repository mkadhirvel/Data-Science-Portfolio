# %% [markdown]
# # DSC 680
# # Project
# # Author: Muthukumar Kadhirvel
# # 23/3/2023

# %% [markdown]
# Install necessary packages and read the rookie dataset and print the properties of the same

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
from scipy import stats
import seaborn as sns
warnings.filterwarnings("ignore")
rookie_df = pd.read_csv('rookie_df.csv')
# Drop unnecessary variable of Unnamed: 0
rookie_df = rookie_df.drop(['Unnamed: 0'], axis = 1)
print(rookie_df.shape)
print(rookie_df.describe())
# Out:
# (1424, 22)
#        Year Drafted           GP          MIN          PTS          FGM  \
# count   1424.000000  1424.000000  1424.000000  1424.000000  1424.000000
# mean    1996.481742    61.131320    17.483216     6.735323     2.602247
# std       10.004199    16.828774     8.265126     4.324453     1.666493
# min     1980.000000    11.000000     3.100000     0.700000     0.300000
# 25%     1988.000000    48.000000    10.900000     3.600000     1.400000
# 50%     1996.000000    64.000000    15.950000     5.500000     2.100000
# 75%     2005.000000    77.000000    23.000000     8.800000     3.400000
# max     2013.000000    82.000000    40.900000    28.200000    10.200000
#
#                FGA          FG%      3P Made          3PA          3P%  ...  \
# count  1424.000000  1424.000000  1424.000000  1424.000000  1424.000000  ...
# mean      5.799930    44.353301     0.238062     0.740520    18.805126  ...
# std       3.545943     6.073722     0.385139     1.057448    16.736753  ...
# ...

# %% [markdown]
# We can see that there are 1424 rows and 22 columns out of which target is the Target Variable and the rest are all continuous Features

# %% [markdown]
# Create Pie Chart for target variable to see how many of the surveyed rookies lasted 5 years in the league

# %%
target_count = rookie_df['target'].value_counts()
plt.pie(target_count,labels = target_count.index, autopct='%1.2f%%')
plt.show()

# %% [markdown]
# We can see that we have around 60% of the surveyed rookies lasted 5 years in the league

# %%
target_0 = rookie_df[rookie_df['target'] == 0]
target_1 = rookie_df[rookie_df['target'] == 1]
target_0_year = list(target_0['Year Drafted'])
target_1_year = list(target_1['Year Drafted'])
plt.figure(figsize=(15,5))
plt.hist([target_0_year, target_1_year], bins = 34)
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# As we can see that 2009 had the most number of rookies who lasted 5 years in the league with 33 with 1988 and 1989 being next with 32 rookies

# %% [markdown]
# Create Histogram for PTS (Average Points Per Game) by overlapping the histogram with the two levels of the target variable to see if there are any changes to the distribution of the numeric variable

# %%
target_0_PTS = list(target_0['PTS'])
target_1_PTS = list(target_1['PTS'])
plt.figure(figsize=(15,5))
plt.hist([target_0_PTS, target_1_PTS])
plt.xlabel('Average Points Per Game')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# We can see that for rookies that score less than 5 points per game they do not last 5 years in the league.

# %% [markdown]
# Create Histograms for GP (Games Played during rookie season) by overlapping the histogram with the two levels of the target variable to see if there are any changes to the distribution of the numeric variable

# %%
target_0_GP = list(target_0['GP'])
target_1_GP = list(target_1['GP'])
plt.figure(figsize=(15,5))
plt.hist([target_0_GP, target_1_GP])
plt.xlabel('Games Played during rookie season')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# We can see that for rookies that play less than 60 games they do not last 5 years in the league.

# %% [markdown]
# Create Histograms for MIN (Minutes Played per game) by overlapping the histogram with the two levels of the target variable to see if there are any changes to the distribution of the numeric variable

# %%
target_0_MIN = list(target_0['MIN'])
target_1_MIN = list(target_1['MIN'])
plt.figure(figsize=(15,5))
plt.hist([target_0_MIN, target_1_MIN])
plt.xlabel('Minutes Played per game')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# We can see that for rookies that play less than 15 minutes per game they do not last 5 years in the league.

# %% [markdown]
# Create Histograms for FG% (Field goals percentage) by overlapping the histogram with the two levels of the target variable to see if there are any changes to the distribution of the numeric variable

# %%
target_0_FG = list(target_0['FG%'])
target_1_FG = list(target_1['FG%'])
plt.figure(figsize=(15,5))
plt.hist([target_0_FG, target_1_FG])
plt.xlabel('Field Goals Percentage')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# We can see that Field goals percentage does not impact target variable

# %% [markdown]
# Create Histograms for 3P% (3 Pointers percentage) by overlapping the histogram with the two levels of the target variable to see if there are any changes to the distribution of the numeric variable

# %%
target_0_3P = list(target_0['3P%'])
target_1_3P = list(target_1['3P%'])
plt.figure(figsize=(15,5))
plt.hist([target_0_3P, target_1_3P])
plt.xlabel('3 Pointers Percentage')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# We can see that 3 Pointers percentage does not impact target variable

# %% [markdown]
# Create scatter plots of FGM/FGA and 3P Made/3PA to examine the relationship between certain numeric variables that are typically tied together in sports analysis

# %%
rookie_df.plot.scatter('FGM','FGA')
    # We can see there is a highly positive correlation between field goals made per game and field goals attempted per game
print(rookie_df['FGM'].corr(rookie_df['FGA']))
# The corr function also returns a high postive correlation value
rookie_df.plot.scatter('3P Made','3PA')
# We can see there is a highly positive correlation between 3-point field goals made per game and 3-point field goals attempted per game
print(rookie_df['3P Made'].corr(rookie_df['3PA']))
# The corr function also returns a high postive correlation value
# Out:
# 0.9804188185905396
# 0.984239141652909

# %% [markdown]
# Find the missing values

# %%
rookie_df.isnull().sum()
# None of the fields have missing values
# Out:
# Year Drafted    0
# GP              0
# MIN             0
# PTS             0
# FGM             0
# FGA             0
# FG%             0
# 3P Made         0
# 3PA             0
# 3P%             0
# FTM             0
# FTA             0
# FT%             0
# OREB            0
# DREB            0
# REB             0
# AST             0
# STL             0
# BLK             0
# TOV             0
# EFF             0
# target          0
# dtype: int64

# %%
# Create correlation matrix as mixture of feature variables against target
# We use pearson correlation as our dataset has just continuous variables
features = rookie_df[rookie_df.columns[rookie_df.columns!='target']]
pearson_matrix = features.corrwith(rookie_df['target'].astype('float'), method='pearson')
print(abs(pearson_matrix))
# We can see from the Correlation Matrix that there are no clear variables that have a good correlation with target variable
# Games Played has the most positive correlation with target variable
# Create heatmap to identify correlation within the other variables as well
plt.figure(figsize=(15,5))
sns.heatmap(rookie_df.corr(), vmin = -1, vmax = 1, annot = True, linewidths=1)
plt.title('Feature Matrix Heatmap')
plt.yticks(rotation = 0)
plt.xticks(rotation = 90)
plt.show()
# We can see that FGM & FGA and 3PMade & 3PA have good correlation which we have identified before as well
# Similarly the below list of variables have good correlation as well
# FGM & PTS
# FGA & PTS
# FTM & FTA
# DREB & REB
# Out:
# Year Drafted    0.018733
# GP              0.355453
# MIN             0.343364
# PTS             0.341491
# FGM             0.338044
# FGA             0.335628
# FG%             0.104089
# 3P Made         0.151678
# 3PA             0.156990
# 3P%             0.165505
# FTM             0.295587
# FTA             0.277605
# FT%             0.172480
# OREB            0.165886
# DREB            0.232696
# REB             0.215648
# AST             0.257487
# STL             0.301582
# BLK             0.100168
# TOV             0.301832
# EFF             0.334143
# dtype: float64

# %% [markdown]
# Create a basic Logistic Regression model as ours is a Classification problem

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score
# Create features matrix with all columns except target
features = rookie_df.drop(['target'], axis = 1)
# Create target vector
target = rookie_df.target
# Create training and test sets with test size being 20%
features_train, features_test, target_train, target_test = train_test_split(features, target, test_size=0.2)
print('Size of training data is',len(features_train))
print('Size of test data is',len(features_test))
# Train an ordinary Logistic regression on the training data.
logit = LogisticRegression()
logit.fit(features_train, target_train)
target_predicted = logit.predict(features_test)
# We use accuracy as the metric as ours is a classification problem
accuracy = accuracy_score(target_test,target_predicted)*100
print('Logistic Regression Model accuracy on the test set is',accuracy)
# We get a good accuracy in the simple Logistic Regression model but accuracy itself is not enough
# Create a confusion matrix for the test set predictions.
matrix = confusion_matrix(target_test, target_predicted)
plt.matshow(matrix,cmap=plt.cm.Blues,alpha=0.5)
for i in range(matrix.shape[0]):
    for j in range(matrix.shape[1]):
        plt.text(x=j, y=i,s=matrix[i, j])
plt.title('Confusion Matrix with Logistic Regression')
plt.xlabel('Predictions')
plt.ylabel('Actuals')
plt.show()
# We can see that the accuracy is 73% and the confusion matrix is also decent enough. But we will still work with other models.
# Out:
# Size of training data is 1139
# Size of test data is 285
# Logistic Regression Model accuracy on the test set is 72.63157894736842

# %% [markdown]
# We will now implement KNN model to see if any differences

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(features_train, target_train)
target_predicted = knn.predict(features_test)
accuracy = accuracy_score(target_test,target_predicted)*100
print('KNN Model accuracy on the test set is',accuracy)
# Create confusion matrix for target_predicted and plot a Confusion Matrix Heat map
matrix = confusion_matrix(target_test, target_predicted)
plt.matshow(matrix,cmap=plt.cm.Blues,alpha=0.5)
for i in range(matrix.shape[0]):
    for j in range(matrix.shape[1]):
        plt.text(x=j, y=i,s=matrix[i, j])
plt.title('Confusion Matrix with KNN')
plt.xlabel('Predictions')
plt.ylabel('Actuals')
plt.show()
# We can see that the accuracy has reduced and so does the confusion matrix compared to Logistic Regression
# Out:
# KNN Model accuracy on the test set is 67.71929824561404

# %% [markdown]
# We will now implement SVM to see if it improves accuracy and confusion matrix

# %%
from sklearn.svm import LinearSVC
clf = LinearSVC().fit(features_train, target_train)
target_predicted = clf.predict(features_test)
accuracy = accuracy_score(target_test,target_predicted)*100
print('Support Vector Machine Model accuracy on the test set is',accuracy)
# Create confusion matrix for target_predicted and plot a Confusion Matrix Heat map
matrix = confusion_matrix(target_test, target_predicted)
plt.matshow(matrix,cmap=plt.cm.Blues,alpha=0.5)
for i in range(matrix.shape[0]):
    for j in range(matrix.shape[1]):
        plt.text(x=j, y=i,s=matrix[i, j])
plt.title('Confusion Matrix with Support Vector Machine Model')
plt.xlabel('Predictions')
plt.ylabel('Actuals')
plt.show()
# We can see that the accuracy is less than Logistic Regression and confusion matrix has lot of false positives
# Out:
# Support Vector Machine Model accuracy on the test set is 67.71929824561404

# %% [markdown]
# We will now create a Random Forest model to see if it fares better

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier()
classifier.fit(features_train, target_train)
target_predicted = classifier.predict(features_test)
accuracy = accuracy_score(target_test,target_predicted)*100
print('Random Forest Classifier Model accuracy on the test set is',accuracy)
# Create confusion matrix for target_predicted and plot a Confusion Matrix Heat map
matrix = confusion_matrix(target_test, target_predicted)
plt.matshow(matrix,cmap=plt.cm.Blues,alpha=0.5)
for i in range(matrix.shape[0]):
    for j in range(matrix.shape[1]):
        plt.text(x=j, y=i,s=matrix[i, j])
plt.title('Confusion Matrix with Random Forest Classifier')
plt.xlabel('Predictions')
plt.ylabel('Actuals')
plt.show()
# We can see that accuracy and confusion matrix for Random Forest Classifier is better than Logistic Regression
# Out:
# Random Forest Classifier Model accuracy on the test set is 72.98245614035088

# %% [markdown]
# Calculate feature score to identify the most important feauture that affects the target variable

# %%
feature_scores = pd.Series(classifier.feature_importances_, index=features_train.columns).sort_values(ascending=False)
feature_scores
# Out:
# GP              0.075771
# MIN             0.069550
# EFF             0.062225
# PTS             0.061984
# FGA             0.058328
# FT%             0.056613
# FGM             0.055979
# FG%             0.055087
# AST             0.048135
# DREB            0.047536
# REB             0.046593
# Year Drafted    0.046477
# 3P%             0.043211
# TOV             0.040467
# FTA             0.039676
# FTM             0.037405
# STL             0.036219
# OREB            0.035820
# BLK             0.033574
# 3PA             0.030944
# 3P Made         0.018411
# dtype: float64

# %%
f, ax = plt.subplots(figsize=(15, 5))
ax = sns.barplot(x=feature_scores[:10], y=feature_scores.index[:10])
ax.set_title("Top 10 Feature Importance Scores against Target Variable")
ax.set_yticklabels(feature_scores.index[:10])
ax.set_xlabel("Feature Importance Score")
ax.set_ylabel("Features")
plt.show()

# %% [markdown]
# We can see that Games Played has the most feature importance and then comes Minutes Played

# %% [markdown]
# We will now perform MinMaxScaler on the dataset and see if it improves accuracy

# %%
# Perform MinMaxScaler on the data
from sklearn.preprocessing import MinMaxScaler
scaled_data = MinMaxScaler().fit_transform(rookie_df)
scaled_rookie_df = pd.DataFrame(scaled_data,columns = rookie_df.columns)
scl_features = scaled_rookie_df.drop(['target'], axis = 1)
scl_target = scaled_rookie_df.target
# Create training and test sets with test size being 20% on the scaled data
scl_features_train,scl_features_test,scl_target_train,scl_target_test = train_test_split(scl_features,scl_target,test_size=0.2)
scl_random = RandomForestClassifier()
scl_random.fit(scl_features_train, scl_target_train)
target_predicted = scl_random.predict(scl_features_test)
accuracy = accuracy_score(scl_target_test,target_predicted)*100
print('Random Forest Classifier Model accuracy on the test set with scaled data is',accuracy)
# Create confusion matrix for target_predicted and plot a Confusion Matrix Heat map
matrix = confusion_matrix(scl_target_test, target_predicted)
plt.matshow(matrix,cmap=plt.cm.Blues,alpha=0.5)
for i in range(matrix.shape[0]):
    for j in range(matrix.shape[1]):
        plt.text(x=j, y=i,s=matrix[i, j])
plt.title('Scaled Data Confusion Matrix with Random Forest Classifier')
plt.xlabel('Predictions')
plt.ylabel('Actuals')
plt.show()
# We can see that the accuracy has not improved and also confusion matrix is more or less same as original
# Out:
# Random Forest Classifier Model accuracy on the test set with scaled data is 69.47368421052632

# %% [markdown]
# Since Random Forest Classifier has the best accuracy and the confusion matrix, we choose that one and go ahead with implementation.
